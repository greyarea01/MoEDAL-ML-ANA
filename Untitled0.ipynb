# %%
#  mount google drive
from google.colab import drive
drive.mount('/content/drive')
# add work area to the PYTHONPATH
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/')

from dataset_tools import mhio
from dataset_tools import image_tools
from dataset_tools import coordinates

imagepath='/content/drive/MyDrive/moedal-examples/all_data_png'

slides = Slide('clean',1,imagepath)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /bin/bash: line 1: cd: /content/drive/MyDrive/Collab Notebooks/: No such file or directory

# %%
# prompt: a function to take an image and a set of coordinates as arguments and return a 28x28 pixel image snipped from the argument centred on the coordinates

from PIL import Image

def crop_image(image_path, center_x, center_y, size=28):
  """
  Crops a 28x28 pixel image from the given image centered on the coordinates.

  Args:
    image_path: Path to the image file.
    center_x: X-coordinate of the center of the crop.
    center_y: Y-coordinate of the center of the crop.
    size: Size of the cropped image (default: 28).

  Returns:
    A PIL Image object representing the cropped image.
  """
  try:
    img = Image.open(image_path)
    width, height = img.size

    # Calculate the top-left corner of the crop
    x1 = int(center_x - size / 2)
    y1 = int(center_y - size / 2)

    # Calculate the bottom-right corner of the crop
    x2 = int(center_x + size / 2)
    y2 = int(center_y + size / 2)

    # Ensure coordinates are within image bounds
    x1 = max(0, x1)
    y1 = max(0, y1)
    x2 = min(width, x2)
    y2 = min(height, y2)

    # Crop the image
    cropped_img = img.crop((x1, y1, x2, y2))

    # Resize to 28x28 if necessary
    if cropped_img.size != (size, size):
      cropped_img = cropped_img.resize((size, size))

    return cropped_img

  except FileNotFoundError:
    print(f"Error: Image file not found at {image_path}")
    return None
  except Exception as e:
    print(f"An error occurred: {e}")
    return None

# %%
import os
print(os.environ['PYTHONPATH'])
# Out:
# /env/python
# ls: cannot access 'gdrive': No such file or directory
