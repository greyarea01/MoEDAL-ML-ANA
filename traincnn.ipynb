# %% [markdown]
# <a href="https://colab.research.google.com/github/yrelisgorau/MoEDAL-ML-ANA/blob/main/traincnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  mount google drive to get access to the data sets
from google.colab import drive
drive.mount('/content/drive')


# clone the repo with the modules (and this file)
# !git clone https://github.com/yrelisgorau/MoEDAL-ML-ANA

# add work area to the PYTHONPATH
import sys
sys.path.append('/content/MoEDAL-ML-ANA/modules')

imagePath='/content/drive/My Drive/Colab Notebooks/moedal-examples/pits_frontback_2d'
# Out:
# Mounted at /content/drive
# Cloning into 'MoEDAL-ML-ANA'...
# remote: Enumerating objects: 268, done.
# remote: Counting objects: 100% (268/268), done.
# remote: Compressing objects: 100% (207/207), done.
# remote: Total 268 (delta 79), reused 235 (delta 59), pack-reused 0 (from 0)
# Receiving objects: 100% (268/268), 7.87 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
import numpy as np
import pickle

import matplotlib.pyplot as plt
def open_pits(file):
    pits = 0
    with open(file,'rb') as pickle_file:
        pits = pickle.load(pickle_file)
    # pits is a dictionary containing signal pits and background pits,
    # for front surface, and reverse surface (r)

    sig = pits['sig']
    sigr = pits['sigr']
    bkg = pits['bkg']
    bkgr = pits['bkgr']
    # pits are stored as a list of tuples
    # pit_tuple = (slide index, x_pos, y_pos, 28*28 numpy array / image)

    pit = sigr[0] # take 1st element in list
    pit = pit[3] # take the image

    sig_images = [ z[3] for z in sig ] # convert sig into a list of images
    sig_array = np.asarray(sig_images) #can convert into array
    bkg_images = [ j[3] for j in bkg ]
    bkg_array = np.asarray(bkg_images)

    """
    making labeled datasets from these lists

    Either use ds label on a list to make a dataset
    this can be concatenated and shuffled with the bkg dataset

    Or generate a label array (see ds label), and use the arrays directly
    """

#    sig_dataset = ds_label(sig_images,(1.0,0.0))
#    bkg_dataset = ds_label(bkg_images,(0.0,1.0))
    sig_label = [(1.0,0.0) for l in sig_array]
    bkg_label = [(0.0,1.0) for l in bkg_array]

    return sig_array, bkg_array, sig_label, bkg_label

# %%
from tensorflow import keras
from tensorflow.keras import layers

def k_sequential():
    """
    Default model used in Xe Ion study
    """
    model = keras.Sequential()
    model.add(keras.Input(shape=(28,28,1))) # specifying input
    model.add(layers.Conv2D(32, kernel_size = (3,3), padding='same',activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.Conv2D(32, kernel_size = (3,3), padding='same',activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.Conv2D(32, kernel_size = (3,3), padding='same',activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.Conv2D(32, kernel_size = (3,3), padding='same',activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.GlobalMaxPooling2D()) # compress to 1 spatial dimension
    model.add(layers.Dense(32, activation = 'relu'))
    model.add(layers.Dense(2, activation = 'softmax'))
    model.summary()
    return model

# %%
from sklearn.model_selection import train_test_split
def training():
    model = k_sequential() # create the compiled model
    s,b,sl,bl = open_pits(imagePath+'/pits_checked') # get the data

    print('opened the inputs',flush=True)
    print(s.shape)
    print(b.shape)

    data_all = np.concatenate((s,b),axis=0)
    label_all = np.concatenate((sl,bl),axis=0)
    print(data_all.shape,label_all.shape)


    data_train, data_test, label_train, label_test  = train_test_split(data_all,label_all,test_size=0.5,random_state=42)
    print(len(data_train),len(label_train))
#
    print('hello', flush=True)


    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=[keras.metrics.BinaryAccuracy, keras.metrics.BinaryCrossentropy],run_eagerly=False)
    print('model compiled',flush=True)
    history = model.fit(data_train,label_train, batch_size = 10, epochs=7,verbose=1,validation_data=(data_test,label_test))

    print('Done',flush=True)
    return history,model

# %%
training()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 4, 4, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 2, 2, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling2d                 │ (None, 32)                  │               0 │
# │ (GlobalMaxPooling2D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,186 (114.01 KB)
#  Trainable params: 29,186 (114.01 KB)
#  Non-trainable params: 0 (0.00 B)
# opened the inputs
# (1299, 28, 28)
# (1471, 28, 28)
# (2770, 28, 28) (2770, 2)
# 1385 1385
# hello
# model compiled
# Epoch 1/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - binary_accuracy: 0.6727 - binary_crossentropy: 0.6058 - loss: 0.5664 - val_binary_accuracy: 0.9256 - val_binary_crossentropy: 0.2984 - val_loss: 0.2311
# Epoch 2/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - binary_accuracy: 0.9260 - binary_crossentropy: 0.3048 - loss: 0.2257 - val_binary_accuracy: 0.9242 - val_binary_crossentropy: 0.3065 - val_loss: 0.2548
# Epoch 3/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - binary_accuracy: 0.9380 - binary_crossentropy: 0.2815 - loss: 0.2118 - val_binary_accuracy: 0.9264 - val_binary_crossentropy: 0.3319 - val_loss: 0.2314
# Epoch 4/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - binary_accuracy: 0.9371 - binary_crossentropy: 0.2892 - loss: 0.2029 - val_binary_accuracy: 0.9256 - val_binary_crossentropy: 0.2889 - val_loss: 0.2217
# Epoch 5/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - binary_accuracy: 0.9278 - binary_crossentropy: 0.2820 - loss: 0.2207 - val_binary_accuracy: 0.9264 - val_binary_crossentropy: 0.2690 - val_loss: 0.2315
# Epoch 6/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - binary_accuracy: 0.9316 - binary_crossentropy: 0.2662 - loss: 0.2105 - val_binary_accuracy: 0.9264 - val_binary_crossentropy: 0.2869 - val_loss: 0.2202
# Epoch 7/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - binary_accuracy: 0.9318 - binary_crossentropy: 0.2753 - loss: 0.2105 - val_binary_accuracy: 0.9249 - val_binary_crossentropy: 0.2888 - val_loss: 0.2257
# Done
# (<keras.src.callbacks.history.History at 0x7cd800676ed0>,
#  <Sequential name=sequential, built=True>)

# %%
def plot_training_metrics(history):
    # Check available keys
    print("Available metrics:", history.history.keys())

    # Extract metrics with correct keys
    acc = history.history.get('binary_accuracy')
    val_acc = history.history.get('val_binary_accuracy')
    loss = history.history.get('loss')
    val_loss = history.history.get('val_loss')

    epochs = range(1, len(acc) + 1)

    # Plot Accuracy
    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.title('Training Accuracy Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Accuracy
    plt.figure()
    plt.plot(epochs, val_acc, label='Validation Accuracy', color='orange')
    plt.title('Validation Accuracy Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Loss
    plt.figure()
    plt.plot(epochs, loss, label='Training Loss', color='red')
    plt.title('Training Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure()
    plt.plot(epochs, val_loss, label='Validation Loss', color='green')
    plt.title('Validation Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
history, model=training()
plot_training_metrics(history)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 14, 14, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 7, 7, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 4, 4, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 2, 2, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling2d_1               │ (None, 32)                  │               0 │
# │ (GlobalMaxPooling2D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,186 (114.01 KB)
#  Trainable params: 29,186 (114.01 KB)
#  Non-trainable params: 0 (0.00 B)
# opened the inputs
# (1299, 28, 28)
# (1471, 28, 28)
# (2770, 28, 28) (2770, 2)
# 1385 1385
# hello
# model compiled
# Epoch 1/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - binary_accuracy: 0.7784 - binary_crossentropy: 0.5570 - loss: 0.4917 - val_binary_accuracy: 0.9206 - val_binary_crossentropy: 0.3571 - val_loss: 0.2506
# Epoch 2/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - binary_accuracy: 0.9218 - binary_crossentropy: 0.3330 - loss: 0.2454 - val_binary_accuracy: 0.9235 - val_binary_crossentropy: 0.3152 - val_loss: 0.2582
# Epoch 3/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - binary_accuracy: 0.9326 - binary_crossentropy: 0.3066 - loss: 0.2295 - val_binary_accuracy: 0.9278 - val_binary_crossentropy: 0.2752 - val_loss: 0.2282
# Epoch 4/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - binary_accuracy: 0.9296 - binary_crossentropy: 0.2920 - loss: 0.2164 - val_binary_accuracy: 0.9271 - val_binary_crossentropy: 0.2790 - val_loss: 0.2283
# Epoch 5/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - binary_accuracy: 0.9264 - binary_crossentropy: 0.2895 - loss: 0.2276 - val_binary_accuracy: 0.9278 - val_binary_crossentropy: 0.2975 - val_loss: 0.2201
# Epoch 6/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - binary_accuracy: 0.9339 - binary_crossentropy: 0.2749 - loss: 0.2030 - val_binary_accuracy: 0.9278 - val_binary_crossentropy: 0.2879 - val_loss: 0.2208
# Epoch 7/7
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - binary_accuracy: 0.9333 - binary_crossentropy: 0.2858 - loss: 0.2076 - val_binary_accuracy: 0.9271 - val_binary_crossentropy: 0.2948 - val_loss: 0.2221
# Done
# Available metrics: dict_keys(['binary_accuracy', 'binary_crossentropy', 'loss', 'val_binary_accuracy', 'val_binary_crossentropy', 'val_loss'])

# %%
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# Overfitting Model

# Overfitting Model (Structured Similar to Base Model)
def overfitting_cnn():
    """
    Overfitting model with structure similar to the base `k_sequential` model.
    """
    model = keras.Sequential()
    model.add(keras.Input(shape=(28, 28, 1)))  # Specifying input
    model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
    model.add(layers.MaxPooling2D(padding='same'))
    model.add(layers.GlobalMaxPooling2D())  # Compress to 1 spatial dimension
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))

    # Increased learning rate for faster convergence
    optimizer = keras.optimizers.Adam(learning_rate=0.005)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model


def train_overfitting_model(imagePath):
    model = overfitting_cnn()

    # load data
    s, b, sl, bl = open_pits(imagePath + '/pits_checked')

    # use only a small subset of data to encourage overfitting
    s = s[:200]
    b = b[:200]
    sl = sl[:200]
    bl = bl[:200]

    # normalize data
    s, b = s / 255.0, b / 255.0

    # prepare data
    data_all = np.concatenate((s, b), axis=0)
    label_all = np.concatenate((sl, bl), axis=0)

    data_train, data_val, label_train, label_val = train_test_split(
        data_all, label_all, test_size=0.5, random_state=42
    )

    # reduced epochs for faster training
    history = model.fit(
        data_train,
        label_train,
        epochs=200,
        batch_size=16,
        validation_data=(data_val, label_val),
        verbose=1
    )

    return history

# plotting validation accuracy

def plot_validation_accuracy(history):
    val_acc = history.history['val_accuracy']
    epochs = range(1, len(val_acc) + 1)

    plt.figure()
    plt.plot(epochs, val_acc, label='Validation Accuracy', color='orange')
    plt.title('Validation Accuracy Over Epochs (Overfitting Demonstration)')
    plt.xlabel('Epochs')
    plt.ylabel('Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
history = train_overfitting_model(imagePath)
plot_validation_accuracy(history)
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.4408 - loss: 0.6999 - val_accuracy: 0.4650 - val_loss: 0.7055
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5796 - loss: 0.6890 - val_accuracy: 0.4650 - val_loss: 0.6953
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5271 - loss: 0.6976 - val_accuracy: 0.4650 - val_loss: 0.6992
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5521 - loss: 0.6921 - val_accuracy: 0.4650 - val_loss: 0.6942
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5294 - loss: 0.6943 - val_accuracy: 0.4650 - val_loss: 0.7267
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5158 - loss: 0.7111 - val_accuracy: 0.4650 - val_loss: 0.7051
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5470 - loss: 0.6890 - val_accuracy: 0.4650 - val_loss: 0.6968
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4582 - loss: 0.6943 - val_accuracy: 0.4650 - val_loss: 0.7121
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4745 - loss: 0.7050 - val_accuracy: 0.4650 - val_loss: 0.6965
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5399 - loss: 0.6945 - val_accuracy: 0.4650 - val_loss: 0.6987
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5427 - loss: 0.6909 - val_accuracy: 0.4650 - val_loss: 0.7234
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5250 - loss: 0.6920 - val_accuracy: 0.4650 - val_loss: 0.7001
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5581 - loss: 0.6876 - val_accuracy: 0.4650 - val_loss: 0.7014
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4966 - loss: 0.6967 - val_accuracy: 0.4650 - val_loss: 0.7001
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5039 - loss: 0.6949 - val_accuracy: 0.4650 - val_loss: 0.7003
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5608 - loss: 0.6871 - val_accuracy: 0.4650 - val_loss: 0.7019
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5194 - loss: 0.6932 - val_accuracy: 0.4650 - val_loss: 0.7008
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5473 - loss: 0.6890 - val_accuracy: 0.4650 - val_loss: 0.7011
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5364 - loss: 0.6906 - val_accuracy: 0.4650 - val_loss: 0.7011
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5031 - loss: 0.6955 - val_accuracy: 0.4650 - val_loss: 0.7005
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5122 - loss: 0.6941 - val_accuracy: 0.4650 - val_loss: 0.7006
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5867 - loss: 0.6837 - val_accuracy: 0.4650 - val_loss: 0.7010
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5565 - loss: 0.6876 - val_accuracy: 0.4650 - val_loss: 0.7006
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5688 - loss: 0.6860 - val_accuracy: 0.4650 - val_loss: 0.7010
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5505 - loss: 0.6884 - val_accuracy: 0.4650 - val_loss: 0.7003
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5381 - loss: 0.6904 - val_accuracy: 0.4650 - val_loss: 0.6999
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5293 - loss: 0.6915 - val_accuracy: 0.4650 - val_loss: 0.7008
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5327 - loss: 0.6911 - val_accuracy: 0.4650 - val_loss: 0.7006
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5232 - loss: 0.6924 - val_accuracy: 0.4650 - val_loss: 0.7008
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5245 - loss: 0.6924 - val_accuracy: 0.4650 - val_loss: 0.7012
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5121 - loss: 0.6942 - val_accuracy: 0.4650 - val_loss: 0.7008
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5171 - loss: 0.6934 - val_accuracy: 0.4650 - val_loss: 0.7005
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4950 - loss: 0.6965 - val_accuracy: 0.4650 - val_loss: 0.6997

# %%
import matplotlib.pyplot as plt
import numpy as np

# function to visualize all pit images in the dataset
def visualize_pit(imagePath, pit_type='sig'):
    """
    Visualizes all pit images from the dataset in a grid.

    Parameters:
    - imagePath: Path to the dataset.
    - pit_type: Type of pit to visualize ('sig', 'bkg').
    """

    # load data
    pits_data = open_pits(imagePath + '/pits_checked')

    # unpack the data
    sig_array, bkg_array, _, _ = pits_data

    # select the pits based on the type
    if pit_type == 'sig':
        pit_images = sig_array
    elif pit_type == 'bkg':
        pit_images = bkg_array
    else:
        raise ValueError("Invalid pit_type. Choose from 'sig' or 'bkg'.")

    # determine grid size
    num_images = len(pit_images)
    grid_size = int(np.ceil(np.sqrt(num_images)))

    # display all pit images in a grid
    fig, axes = plt.subplots(grid_size, grid_size, figsize=(12, 12))
    fig.suptitle(f'All {pit_type.upper()} Pit Images', fontsize=16)

    for i in range(grid_size * grid_size):
        row, col = divmod(i, grid_size)
        ax = axes[row, col]

        if i < num_images:
            ax.imshow(pit_images[i], cmap='gray')
            ax.axis('off')
        else:
            ax.axis('off')  # hide empty subplots

    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

# %%
visualize_pit(imagePath, pit_type='sig')

# %% [markdown]
# Below is the cross validation code

# %%
from sklearn.model_selection import KFold
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# function for cross-validation training
def cross_validation_training(imagePath, n_splits=5):
    """
    Perform k-fold cross-validation for CNN training using the base model structure.

    Parameters:
    - imagePath: Path to the dataset.
    - n_splits: Number of folds for cross-validation (default is 5).
    """

    # load data
    s, b, sl, bl = open_pits(imagePath + '/pits_checked')

    # normalize data
    s, b = s / 255.0, b / 255.0

    # prepare data and labels
    data_all = np.concatenate((s, b), axis=0)
    label_all = np.concatenate((sl, bl), axis=0)

    # initialize KFold
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold_accuracies = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(data_all)):
        print(f'\nTraining on Fold {fold + 1}/{n_splits}')

        # split data
        data_train, data_val = data_all[train_idx], data_all[val_idx]
        label_train, label_val = label_all[train_idx], label_all[val_idx]

        # define model (base model structure)
        model = keras.Sequential()
        model.add(keras.Input(shape=(28, 28, 1)))  # Specifying input
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.GlobalMaxPooling2D())  # Compress to 1 spatial dimension
        model.add(layers.Dense(32, activation='relu'))
        model.add(layers.Dense(2, activation='softmax'))

        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # train model
        history = model.fit(
            data_train,
            label_train,
            epochs=10,  # Adjust epochs as needed
            batch_size=32,
            validation_data=(data_val, label_val),
            verbose=1
        )

        # evaluate model
        val_accuracy = history.history['val_accuracy'][-1]
        fold_accuracies.append(val_accuracy)
        print(f'Fold {fold + 1} Validation Accuracy: {val_accuracy:.4f}')

    # average accuracy across folds
    avg_accuracy = np.mean(fold_accuracies)
    print(f'\nAverage Validation Accuracy Across {n_splits} Folds: {avg_accuracy:.4f}')

    return fold_accuracies, avg_accuracy

# %%
fold_accuracies, avg_accuracy = cross_validation_training(imagePath, n_splits=5)
# Out:
# Training on Fold 1/5
# Epoch 1/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.5129 - loss: 0.6930 - val_accuracy: 0.5217 - val_loss: 0.6927
# Epoch 2/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5099 - loss: 0.6941 - val_accuracy: 0.5217 - val_loss: 0.6921
# Epoch 3/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.5366 - loss: 0.6908 - val_accuracy: 0.5217 - val_loss: 0.6812
# Epoch 4/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.6986 - loss: 0.5892 - val_accuracy: 0.9224 - val_loss: 0.2753
# Epoch 5/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9155 - loss: 0.2524 - val_accuracy: 0.9170 - val_loss: 0.2329
# Epoch 6/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9234 - loss: 0.2377 - val_accuracy: 0.9097 - val_loss: 0.2522
# Epoch 7/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9158 - loss: 0.2542 - val_accuracy: 0.9152 - val_loss: 0.2288
# Epoch 8/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9289 - loss: 0.2232 - val_accuracy: 0.9097 - val_loss: 0.2429
# Epoch 9/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9214 - loss: 0.2312 - val_accuracy: 0.9242 - val_loss: 0.2312
# Epoch 10/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9322 - loss: 0.2184 - val_accuracy: 0.9242 - val_loss: 0.2274
# Fold 1 Validation Accuracy: 0.9242
#
# Training on Fold 2/5
# Epoch 1/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.5286 - loss: 0.6930 - val_accuracy: 0.5379 - val_loss: 0.6902
# Epoch 2/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.5185 - loss: 0.6930 - val_accuracy: 0.5379 - val_loss: 0.6894
# Epoch 3/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.5432 - loss: 0.6850 - val_accuracy: 0.7708 - val_loss: 0.5079
# Epoch 4/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8689 - loss: 0.3765 - val_accuracy: 0.9260 - val_loss: 0.2723
# Epoch 5/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9053 - loss: 0.2876 - val_accuracy: 0.8935 - val_loss: 0.2759
# Epoch 6/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.9258 - loss: 0.2229 - val_accuracy: 0.9242 - val_loss: 0.2286
# Epoch 7/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9297 - loss: 0.2173 - val_accuracy: 0.9260 - val_loss: 0.2282
# Epoch 8/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9258 - loss: 0.2213 - val_accuracy: 0.9296 - val_loss: 0.2318
# Epoch 9/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9237 - loss: 0.2264 - val_accuracy: 0.9224 - val_loss: 0.2374
# Epoch 10/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9205 - loss: 0.2401 - val_accuracy: 0.9188 - val_loss: 0.2507
# Fold 2 Validation Accuracy: 0.9188
#
# Training on Fold 3/5
# Epoch 1/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.5076 - loss: 0.6933 - val_accuracy: 0.5415 - val_loss: 0.6901
# Epoch 2/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.5276 - loss: 0.6915 - val_accuracy: 0.5415 - val_loss: 0.6764
# Epoch 3/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7192 - loss: 0.5727 - val_accuracy: 0.8935 - val_loss: 0.2945
# Epoch 4/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9079 - loss: 0.2756 - val_accuracy: 0.8953 - val_loss: 0.2618
# Epoch 5/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9154 - loss: 0.2448 - val_accuracy: 0.8989 - val_loss: 0.2631
# Epoch 6/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9184 - loss: 0.2448 - val_accuracy: 0.9206 - val_loss: 0.2401
# Epoch 7/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9232 - loss: 0.2438 - val_accuracy: 0.9097 - val_loss: 0.2488
# Epoch 8/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9295 - loss: 0.2237 - val_accuracy: 0.9242 - val_loss: 0.2358
# Epoch 9/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9369 - loss: 0.2074 - val_accuracy: 0.9260 - val_loss: 0.2337
# Epoch 10/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9283 - loss: 0.2239 - val_accuracy: 0.9134 - val_loss: 0.2419
# Fold 3 Validation Accuracy: 0.9134
#
# Training on Fold 4/5
# Epoch 1/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.5388 - loss: 0.6924 - val_accuracy: 0.5217 - val_loss: 0.6919
# Epoch 2/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5321 - loss: 0.6902 - val_accuracy: 0.6426 - val_loss: 0.6700
# Epoch 3/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8157 - loss: 0.5101 - val_accuracy: 0.8953 - val_loss: 0.4352
# Epoch 4/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9093 - loss: 0.2665 - val_accuracy: 0.8736 - val_loss: 0.3336
# Epoch 5/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9004 - loss: 0.2794 - val_accuracy: 0.8881 - val_loss: 0.2889
# Epoch 6/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9051 - loss: 0.2566 - val_accuracy: 0.9206 - val_loss: 0.2761
# Epoch 7/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9309 - loss: 0.2176 - val_accuracy: 0.9116 - val_loss: 0.2644
# Epoch 8/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9243 - loss: 0.2280 - val_accuracy: 0.9152 - val_loss: 0.2589
# Epoch 9/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9229 - loss: 0.2391 - val_accuracy: 0.9170 - val_loss: 0.2914
# Epoch 10/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9159 - loss: 0.2364 - val_accuracy: 0.9170 - val_loss: 0.2824
# Fold 4 Validation Accuracy: 0.9170
#
# Training on Fold 5/5
# Epoch 1/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.4941 - loss: 0.6929 - val_accuracy: 0.5325 - val_loss: 0.6916
# Epoch 2/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5352 - loss: 0.6897 - val_accuracy: 0.9278 - val_loss: 0.6271
# Epoch 3/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7812 - loss: 0.5482 - val_accuracy: 0.9332 - val_loss: 0.2419
# Epoch 4/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9130 - loss: 0.2647 - val_accuracy: 0.9242 - val_loss: 0.2143
# Epoch 5/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9123 - loss: 0.2517 - val_accuracy: 0.9458 - val_loss: 0.1977
# Epoch 6/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9164 - loss: 0.2526 - val_accuracy: 0.9296 - val_loss: 0.2104
# Epoch 7/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.9026 - loss: 0.2717 - val_accuracy: 0.9314 - val_loss: 0.2149
# Epoch 8/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9199 - loss: 0.2491 - val_accuracy: 0.9260 - val_loss: 0.2264
# Epoch 9/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9194 - loss: 0.2331 - val_accuracy: 0.9386 - val_loss: 0.2056
# Epoch 10/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9151 - loss: 0.2516 - val_accuracy: 0.9422 - val_loss: 0.1998
# Fold 5 Validation Accuracy: 0.9422
#
# Average Validation Accuracy Across 5 Folds: 0.9231

# %% [markdown]
# Below is utilising bootstrap method

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import resample

# function to perform bootstrap sampling and calculate variance
def bootstrap_model_variance(imagePath, n_iterations=10):
    """
    Perform bootstrap sampling to evaluate model variance using the base model structure.

    Parameters:
    - imagePath: Path to the dataset.
    - n_iterations: Number of bootstrap samples (default is 10).
    """

    # load data
    s, b, sl, bl = open_pits(imagePath + '/pits_checked')

    # normalize data
    s, b = s / 255.0, b / 255.0

    # prepare data and labels
    data_all = np.concatenate((s, b), axis=0)
    label_all = np.concatenate((sl, bl), axis=0)

    accuracies = []

    for i in range(n_iterations):
        print(f'\nBootstrap Iteration {i + 1}/{n_iterations}')

        # bootstrap sampling
        data_sample, label_sample = resample(data_all, label_all, replace=True, random_state=i)

        # define model (base model structure)
        model = keras.Sequential()
        model.add(keras.Input(shape=(28, 28, 1)))  # specifying input
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh'))
        model.add(layers.MaxPooling2D(padding='same'))
        model.add(layers.GlobalMaxPooling2D())  # compress to 1 spatial dimension
        model.add(layers.Dense(32, activation='relu'))
        model.add(layers.Dense(2, activation='softmax'))

        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # train model
        history = model.fit(
            data_sample,
            label_sample,
            epochs=10,  # adjust epochs as needed
            batch_size=32,
            verbose=0  # suppress output for cleaner results
        )

        # evaluate the model
        final_accuracy = history.history['accuracy'][-1]
        accuracies.append(final_accuracy)
        print(f'Iteration {i + 1} Accuracy: {final_accuracy:.4f}')

    # calculate variance
    variance = np.var(accuracies)
    print(f'\nVariance of Model Accuracy Across {n_iterations} Bootstrap Samples: {variance:.6f}')

    return accuracies, variance

# %%
accuracies, variance = bootstrap_model_variance(imagePath, n_iterations=10)
# Out:
# Bootstrap Iteration 1/10
# Iteration 1 Accuracy: 0.9300
#
# Bootstrap Iteration 2/10
# Iteration 2 Accuracy: 0.9332
#
# Bootstrap Iteration 3/10
# Iteration 3 Accuracy: 0.9274
#
# Bootstrap Iteration 4/10
# Iteration 4 Accuracy: 0.9274
#
# Bootstrap Iteration 5/10
# Iteration 5 Accuracy: 0.9318
#
# Bootstrap Iteration 6/10
# Iteration 6 Accuracy: 0.9321
#
# Bootstrap Iteration 7/10
# Iteration 7 Accuracy: 0.9285
#
# Bootstrap Iteration 8/10
# Iteration 8 Accuracy: 0.9292
#
# Bootstrap Iteration 9/10
# Iteration 9 Accuracy: 0.9307
#
# Bootstrap Iteration 10/10
# Iteration 10 Accuracy: 0.9329
#
# Variance of Model Accuracy Across 10 Bootstrap Samples: 0.000004

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2

# function to create a heatmap for pit detection
def generate_pit_heatmap(imagePath, image_index=0):
    """
    Generate a heatmap to visualize pit detection results using the base model.

    Parameters:
    - imagePath: Path to the dataset.
    - image_index: Index of the image to generate the heatmap for.
    """

    # load the dataset
    s, _, _, _ = open_pits(imagePath + '/pits_checked')

    # select a sample image
    img = s[image_index]  # grayscale image
    img = img / 255.0  # normalize
    img_input = np.expand_dims(img, axis=(0, -1))  # reshape for model

    # define the base model
    def create_base_model():
        inputs = keras.Input(shape=(28, 28, 1))
        x = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh')(inputs)
        x = layers.MaxPooling2D(padding='same')(x)
        x = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh')(x)
        x = layers.MaxPooling2D(padding='same')(x)
        x = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh')(x)
        x = layers.MaxPooling2D(padding='same')(x)
        x = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='tanh')(x)
        x = layers.MaxPooling2D(padding='same')(x)
        x = layers.GlobalMaxPooling2D()(x)
        x = layers.Dense(32, activation='relu')(x)
        outputs = layers.Dense(2, activation='softmax')(x)
        return keras.Model(inputs, outputs)

    model = create_base_model()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # identify the last convolutional layer dynamically
    conv_layers = [layer for layer in model.layers if isinstance(layer, layers.Conv2D)]
    if not conv_layers:
        raise ValueError("No Conv2D layer found in the model.")
    last_conv_layer = conv_layers[-1]

    # create a model that outputs the feature maps from the last conv layer
    heatmap_model = keras.Model(inputs=model.input, outputs=last_conv_layer.output)

    # get feature map
    feature_map = heatmap_model.predict(img_input)
    feature_map = np.squeeze(feature_map)  # Remove batch dimension

    # resize heatmap to match original image size
    heatmap = cv2.resize(feature_map.mean(axis=-1), (28, 28))

    # normalize heatmap
    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap) if np.max(heatmap) > 0 else 1

    # plot heatmap
    plt.figure(figsize=(6, 6))
    plt.imshow(img, cmap='gray', alpha=0.5)
    plt.imshow(heatmap, cmap='jet', alpha=0.5)
    plt.colorbar()
    plt.title("Pit Detection Heatmap")
    plt.axis("off")
    plt.show()

# example usage
# generate_pit_heatmap(imagePath, image_index=0)

# %%
generate_pit_heatmap(imagePath, image_index=5)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cd7f0afbe20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
